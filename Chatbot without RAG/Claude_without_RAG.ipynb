# %%
pip install anthropic
# Out:
# ...
#   Using cached anthropic-0.31.2-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
# Using cached anthropic-0.31.2-py3-none-any.whl (865 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...

# %%
import anthropic
import os
import sys

# %%
llm1 = anthropic.Anthropic(api_key="YOUR_API_KEYS")

# %%
def Normal_LLM(query, llm1, chat_history):

    full_query = "\n".join([f"User: {q}\nAssistance: {a}" for q, a in chat_history])
    full_query += f"\nUser: {query}"

    chain1 = llm1.messages.create(
        model="claude-3-5-sonnet-20240620",
        max_tokens=1000,
        system="You are a world-class poet. Respond only with short poems.",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": full_query
                    }
                ]
            }
        ]
    )

    result = chain1.content[0].text

    return result

# %%
chat_history = []
query = None  # Initialize query to avoid potential reference error

while True:
    if not query:
        query = input("User: ")
    if query in ['quit', 'q', 'exit']:
        break
    result = Normal_LLM(query, llm1, chat_history)
    print("Chatbot:", result)

    chat_history.append((query, result))
    query = None
# Out:
# User: create 1 week Japan trip for me and show it in a table.
# Chatbot: Cherry blossoms float,
# A journey unfolds in rows,
# Japan's wonders bloom.
#
# | Day | Location | Activities |
# |-----|----------|------------|
# | 1   | Tokyo    | Neon dreams, skyscrapers gleam |
# | 2   | Kyoto    | Temples whisper ancient tales |
# | 3   | Nara     | Deer bow, history's gentle grace |
# | 4   | Hiroshima| Peace cranes soar, hearts reflect |
# | 5   | Miyajima | Torii gate, tides ebb and flow |
# | 6   | Osaka    | Street food sizzles, laughter rings |
# | 7   | Mt. Fuji | Climb to clouds, spirits soar high |
# User: q
